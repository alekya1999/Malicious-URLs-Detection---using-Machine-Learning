# %%
import requests
from bs4 import BeautifulSoup

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import time

url = 'https://phishtank.org/phish_archive.php?page={}'
max_pages = 10 # set the number of pages you want to scrape
pause_time = 2  # set the pause time in seconds

trs = []
ids = []
phish_url = []
submitted = []
valid = []
online = []
date_added = []

for page in range(0, max_pages+201):
#     print(f"Scraping page {page}")
    page_url = url.format(page)
    response = requests.get(page_url).text
    soup = BeautifulSoup(response, features="html.parser")
    trs += soup.find_all("td", class_="value")
#     print(f"Number of entries collected so far: {len(trs)}")
    time.sleep(pause_time)

for i in range(0,len(trs)):
    j = i % 5
    if i == 0 or j == 0:
        ids.append(trs[i].text)
        flag=trs[i].text
    elif i != 0 and j % 4 == 0:
        online.append(trs[i].text)
    elif i != 0 and j % 3 == 0:
        valid.append(trs[i].text)
    elif i != 0 and j % 2 == 0:
        #submitted.append(trs[i].text)
        pass
    else:
        phish_url.append(trs[i].contents[0].text)

data = {
    'id': ids,
    'phish_url': phish_url,
#    'submit_time': submitted,
    'valid': valid,
    'online': online
}

flag=0

df = pd.DataFrame(data)

url1 = 'https://phishtank.org/phish_detail.php?phish_id={}'


# for flag in df['id']:
#     page_url1 = url1.format(flag)
#     response1 = requests.get(page_url1).text
#     soup1 = BeautifulSoup(response1, features="html.parser")
#     trs1 = soup1.find_all("span")
#     time.sleep(pause_time)
#     pd.set_option('display.max_colwidth', None)
#     df['new phish_url']=repr(trs1[2].text)
            
print(df)
df.to_csv('phish_data.csv', index=False)
# Out:
#            id                                          phish_url        valid  \
# 0     8136774      https://express.adobe.com/page/fK87pF5GlFp3H/      Unknown
# 1     8136773                                http://cmccanna.com      Unknown
# 2     8136772        https://strangecarefulfeed--082400.repl.co/      Unknown
# 3     8136771  https://4b7730ae-5eac-48db-89c1-fff1d063df05.i...      Unknown
# 4     8136770                   https://novedaddesistem.repl.co/      Unknown
# ...       ...                                                ...          ...
# 4215  8132559  SPAMs://sites.google.com/view/aguiarassessoria...      Unknown
# 4216  8132558                   SPAMs://linktr.ee/faleconoscooat      Unknown
# 4217  8132557                        https://naijalee.com/credem      Unknown
# 4218  8132556                           https://is.gd/Credem_APP  VALID PHISH
# 4219  8132555                            SPAMs://infocomplet.com      Unknown
#
#        online
# 0      ONLINE
# ...

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import time

url = 'https://phishtank.org/phish_archive.php?page={}'


trs = []
ids = []
phish_url = []
submitted = []
valid = []
online = []
date_added = []

for page in range(max_pages+201, max_pages+402):
#     print(f"Scraping page {page}")
    page_url = url.format(page)
    response = requests.get(page_url).text
    soup = BeautifulSoup(response, features="html.parser")
    trs += soup.find_all("td", class_="value")
#     print(f"Number of entries collected so far: {len(trs)}")
    time.sleep(pause_time)

for i in range(0,len(trs)):
    j = i % 5
    if i == 0 or j == 0:
        ids.append(trs[i].text)
        flag=trs[i].text
    elif i != 0 and j % 4 == 0:
        online.append(trs[i].text)
    elif i != 0 and j % 3 == 0:
        valid.append(trs[i].text)
    elif i != 0 and j % 2 == 0:
        #submitted.append(trs[i].text)
        pass
    else:
        phish_url.append(trs[i].contents[0].text)

data = {
    'id': ids,
    'phish_url': phish_url,
#    'submit_time': submitted,
    'valid': valid,
    'online': online
}

flag=0

df = pd.DataFrame(data)

url1 = 'https://phishtank.org/phish_detail.php?phish_id={}'


# for flag in df['id']:
#     page_url1 = url1.format(flag)
#     response1 = requests.get(page_url1).text
#     soup1 = BeautifulSoup(response1, features="html.parser")
#     trs1 = soup1.find_all("span")
#     time.sleep(pause_time)
#     pd.set_option('display.max_colwidth', None)
#     df['new phish_url']=repr(trs1[2].text)
            
print(df)
df.to_csv('phish_data1.csv', index=False)
# Out:
#            id                                          phish_url        valid  \
# 0     8132554       https://www.join-galagames-community-app.com      Unknown
# 1     8132553       https://autoscout24.dealerating-acountid.ch/  VALID PHISH
# 2     8132552  https://autoscout24.dealerrating-acountid.com/...      Unknown
# 3     8132551                 https://myisolved.istp-hcm.online/      Unknown
# 4     8132550                  http://myisolved.istp-hcm.online/      Unknown
# ...       ...                                                ...          ...
# 4015  8128539                         http://edca.org.ec/Push-it  VALID PHISH
# 4016  8128538  http://dkb-account-einloggen.ftpaccess.cc/acce...  VALID PHISH
# 4017  8128537  https://shimmeringskeletalconditional.tolozah....      Unknown
# 4018  8128536             https://tuanyuane.com/mufg/address.php  VALID PHISH
# 4019  8128535              https://activaci0nenlineaabril.store/  VALID PHISH
#
#        online
# 0     Offline
# ...

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import time

url = 'https://phishtank.org/phish_archive.php?page={}'


trs = []
ids = []
phish_url = []
submitted = []
valid = []
online = []
date_added = []

for page in range(max_pages+402, max_pages+602):
#     print(f"Scraping page {page}")
    page_url = url.format(page)
    response = requests.get(page_url).text
    soup = BeautifulSoup(response, features="html.parser")
    trs += soup.find_all("td", class_="value")
#     print(f"Number of entries collected so far: {len(trs)}")
    time.sleep(pause_time)

for i in range(0,len(trs)):
    j = i % 5
    if i == 0 or j == 0:
        ids.append(trs[i].text)
        flag=trs[i].text
    elif i != 0 and j % 4 == 0:
        online.append(trs[i].text)
    elif i != 0 and j % 3 == 0:
        valid.append(trs[i].text)
    elif i != 0 and j % 2 == 0:
        #submitted.append(trs[i].text)
        pass
    else:
        phish_url.append(trs[i].contents[0].text)

data = {
    'id': ids,
    'phish_url': phish_url,
#    'submit_time': submitted,
    'valid': valid,
    'online': online
}

flag=0

df = pd.DataFrame(data)

url1 = 'https://phishtank.org/phish_detail.php?phish_id={}'


# for flag in df['id']:
#     page_url1 = url1.format(flag)
#     response1 = requests.get(page_url1).text
#     soup1 = BeautifulSoup(response1, features="html.parser")
#     trs1 = soup1.find_all("span")
#     time.sleep(pause_time)
#     pd.set_option('display.max_colwidth', None)
#     df['new phish_url']=repr(trs1[2].text)
            
print(df)
df.to_csv('phish_data2.csv', index=False)
# Out:
#            id                                          phish_url        valid  \
# 0     8128534  https://stalesayhnmkollndyusers.tolozah.repl.c...      Unknown
# 1     8128533      https://starryoffensiveadmins.tolozah.repl.co      Unknown
# 2     8128532             http://aprobadoenlinea-creditobpc.bio/  VALID PHISH
# 3     8128531                      https://www.securitasinc.com/      Unknown
# 4     8128530                       http://www.securitasusa.com/      Unknown
# ...       ...                                                ...          ...
# 3995  8124539  https://quantforcecapital.com/login/client/isp...  VALID PHISH
# 3996  8124538                     https://quantforcecapital.com/  VALID PHISH
# 3997  8124537        https://baoweixia.com/login/client/ispc.php  VALID PHISH
# 3998  8124536                             https://baoweixia.com/  VALID PHISH
# 3999  8124535  https://simplerfishing.com/login/client/ispc.p...  VALID PHISH
#
#        online
# 0     Offline
# ...

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import time

url = 'https://phishtank.org/phish_archive.php?page={}'


trs = []
ids = []
phish_url = []
submitted = []
valid = []
online = []
date_added = []

for page in range(max_pages+602, max_pages+802):
#     print(f"Scraping page {page}")
    page_url = url.format(page)
    response = requests.get(page_url).text
    soup = BeautifulSoup(response, features="html.parser")
    trs += soup.find_all("td", class_="value")
#     print(f"Number of entries collected so far: {len(trs)}")
    time.sleep(pause_time)

for i in range(0,len(trs)):
    j = i % 5
    if i == 0 or j == 0:
        ids.append(trs[i].text)
        flag=trs[i].text
    elif i != 0 and j % 4 == 0:
        online.append(trs[i].text)
    elif i != 0 and j % 3 == 0:
        valid.append(trs[i].text)
    elif i != 0 and j % 2 == 0:
        #submitted.append(trs[i].text)
        pass
    else:
        phish_url.append(trs[i].contents[0].text)

data = {
    'id': ids,
    'phish_url': phish_url,
#    'submit_time': submitted,
    'valid': valid,
    'online': online
}

flag=0

df = pd.DataFrame(data)

url1 = 'https://phishtank.org/phish_detail.php?phish_id={}'


# for flag in df['id']:
#     page_url1 = url1.format(flag)
#     response1 = requests.get(page_url1).text
#     soup1 = BeautifulSoup(response1, features="html.parser")
#     trs1 = soup1.find_all("span")
#     time.sleep(pause_time)
#     pd.set_option('display.max_colwidth', None)
#     df['new phish_url']=repr(trs1[2].text)
            
print(df)
df.to_csv('phish_data3.csv', index=False)
# Out:
#            id                                          phish_url        valid  \
# 0     8124534                        https://simplerfishing.com/  VALID PHISH
# 1     8124533        https://direot.smtb.jp.aip1-ib-login-do.top  VALID PHISH
# 2     8124532                          https://cloudcentery.com/  VALID PHISH
# 3     8124531  http://www.promericasegurid.byethost7.com/?i=1...  VALID PHISH
# 4     8124530         http://www.aeocn-co-jp.aceon.bsjdw30i.top/  VALID PHISH
# ...       ...                                                ...          ...
# 3995  8120540                       http://zeonline-bebidas.com/      Unknown
# 3996  8120539  https://distribuidorabebidas.com/produto.php?i...      Unknown
# 3997  8120538              https://myethereumwallet.netlify.app/  VALID PHISH
# 3998  8120537                https://hagdaor.wixsite.com/my-site  VALID PHISH
# 3999  8120536  https://docs.google.com/presentation/d/e/2PACX...  VALID PHISH
#
#        online
# 0     Offline
# ...

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import time

url = 'https://phishtank.org/phish_archive.php?page={}'


trs = []
ids = []
phish_url = []
submitted = []
valid = []
online = []
date_added = []

for page in range(max_pages+802, max_pages+1002):
#     print(f"Scraping page {page}")
    page_url = url.format(page)
    response = requests.get(page_url).text
    soup = BeautifulSoup(response, features="html.parser")
    trs += soup.find_all("td", class_="value")
#     print(f"Number of entries collected so far: {len(trs)}")
    time.sleep(pause_time)

for i in range(0,len(trs)):
    j = i % 5
    if i == 0 or j == 0:
        ids.append(trs[i].text)
        flag=trs[i].text
    elif i != 0 and j % 4 == 0:
        online.append(trs[i].text)
    elif i != 0 and j % 3 == 0:
        valid.append(trs[i].text)
    elif i != 0 and j % 2 == 0:
        #submitted.append(trs[i].text)
        pass
    else:
        phish_url.append(trs[i].contents[0].text)

data = {
    'id': ids,
    'phish_url': phish_url,
#    'submit_time': submitted,
    'valid': valid,
    'online': online
}

flag=0

df = pd.DataFrame(data)

url1 = 'https://phishtank.org/phish_detail.php?phish_id={}'


# for flag in df['id']:
#     page_url1 = url1.format(flag)
#     response1 = requests.get(page_url1).text
#     soup1 = BeautifulSoup(response1, features="html.parser")
#     trs1 = soup1.find_all("span")
#     time.sleep(pause_time)
#     pd.set_option('display.max_colwidth', None)
#     df['new phish_url']=repr(trs1[2].text)
            
print(df)
df.to_csv('phish_data4.csv', index=False)
# Out:
#            id                                          phish_url        valid  \
# 0     8120535  https://adbsignature.web.app/BM2ark17i2Pndy9bF...  VALID PHISH
# 1     8120534                            https://t.co/2bXRIKilJc      Unknown
# 2     8120533                            https://t.co/pF4WVzzIot  VALID PHISH
# 3     8120532  https://carnavaldeofertas.com/01723360/produto...      Unknown
# 4     8120531  https://jmsaxenaassociaties.com/wp-admin/httpd...  VALID PHISH
# ...       ...                                                ...          ...
# 3995  8116542  https://bafkreibgveidnvi7lwbdndtikzdmoqp6e4dpw...  VALID PHISH
# 3996  8116541  https://bafybeic7x7s7vlzzudbodd2nijpsj4eipk6f6...  VALID PHISH
# 3997  8116540  https://bafybeibgucf7zhtxuihjhlvjprarigx346awv...  VALID PHISH
# 3998  8116539  https://bafkreifv2jqfxlng3irj3xr64v3ha57am4zgs...  VALID PHISH
# 3999  8116538                          https://ysnet.boxmode.io/  VALID PHISH
#
#        online
# 0     Offline
# ...

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import time

url = 'https://phishtank.org/phish_archive.php?page={}'


trs = []
ids = []
phish_url = []
submitted = []
valid = []
online = []
date_added = []

for page in range(max_pages+1002, max_pages+1202):
#     print(f"Scraping page {page}")
    page_url = url.format(page)
    response = requests.get(page_url).text
    soup = BeautifulSoup(response, features="html.parser")
    trs += soup.find_all("td", class_="value")
#     print(f"Number of entries collected so far: {len(trs)}")
    time.sleep(pause_time)

for i in range(0,len(trs)):
    j = i % 5
    if i == 0 or j == 0:
        ids.append(trs[i].text)
        flag=trs[i].text
    elif i != 0 and j % 4 == 0:
        online.append(trs[i].text)
    elif i != 0 and j % 3 == 0:
        valid.append(trs[i].text)
    elif i != 0 and j % 2 == 0:
        #submitted.append(trs[i].text)
        pass
    else:
        phish_url.append(trs[i].contents[0].text)

data = {
    'id': ids,
    'phish_url': phish_url,
#    'submit_time': submitted,
    'valid': valid,
    'online': online
}

flag=0

df = pd.DataFrame(data)

url1 = 'https://phishtank.org/phish_detail.php?phish_id={}'


# for flag in df['id']:
#     page_url1 = url1.format(flag)
#     response1 = requests.get(page_url1).text
#     soup1 = BeautifulSoup(response1, features="html.parser")
#     trs1 = soup1.find_all("span")
#     time.sleep(pause_time)
#     pd.set_option('display.max_colwidth', None)
#     df['new phish_url']=repr(trs1[2].text)
            
print(df)
df.to_csv('phish_data5.csv', index=False)
# Out:
#            id                                          phish_url        valid  \
# 0     8116537  https://accounts.mail.wesfrgpay.com/v3/signin/...  VALID PHISH
# 1     8116536  https://ipfs.io/ipfs/Qmdexfm7Pmp2ZKjfdsfovgsus...  VALID PHISH
# 2     8116535  https://sprikk-1316850103.cos.ap-tokyo.myqclou...  VALID PHISH
# 3     8116534  https://sigmacumlaude-1316850103.cos.sa-saopau...  VALID PHISH
# 4     8116533  https://senecaedizioni-1316850103.cos.eu-frank...  VALID PHISH
# ...       ...                                                ...          ...
# 3995  8112543  http://www--wellsfargo--com--u749329d48d6c.wsi...      Unknown
# 3996  8112542  http://www--wellsfargo--com--t849329d48d6c.wsi...      Unknown
# 3997  8112541  http://www--wellsfargo--com--r349329d48d6c.wsi...      Unknown
# 3998  8112540                     https://rofaxebawo.weebly.com/      Unknown
# 3999  8112539                      http://rofaxebawo.weebly.com/      Unknown
#
#        online
# 0      ONLINE
# ...

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import time

url = 'https://phishtank.org/phish_archive.php?page={}'


trs = []
ids = []
phish_url = []
submitted = []
valid = []
online = []
date_added = []

for page in range(max_pages+1202, max_pages+1402):
#     print(f"Scraping page {page}")
    page_url = url.format(page)
    response = requests.get(page_url).text
    soup = BeautifulSoup(response, features="html.parser")
    trs += soup.find_all("td", class_="value")
#     print(f"Number of entries collected so far: {len(trs)}")
    time.sleep(pause_time)

for i in range(0,len(trs)):
    j = i % 5
    if i == 0 or j == 0:
        ids.append(trs[i].text)
        flag=trs[i].text
    elif i != 0 and j % 4 == 0:
        online.append(trs[i].text)
    elif i != 0 and j % 3 == 0:
        valid.append(trs[i].text)
    elif i != 0 and j % 2 == 0:
        #submitted.append(trs[i].text)
        pass
    else:
        phish_url.append(trs[i].contents[0].text)

data = {
    'id': ids,
    'phish_url': phish_url,
#    'submit_time': submitted,
    'valid': valid,
    'online': online
}

flag=0

df = pd.DataFrame(data)

url1 = 'https://phishtank.org/phish_detail.php?phish_id={}'


# for flag in df['id']:
#     page_url1 = url1.format(flag)
#     response1 = requests.get(page_url1).text
#     soup1 = BeautifulSoup(response1, features="html.parser")
#     trs1 = soup1.find_all("span")
#     time.sleep(pause_time)
#     pd.set_option('display.max_colwidth', None)
#     df['new phish_url']=repr(trs1[2].text)
            
print(df)
df.to_csv('phish_data6.csv', index=False)
# Out:
#            id                                          phish_url        valid  \
# 0     8112538  https://www.indushealthplus.com/common/comps/a...  VALID PHISH
# 1     8112537                           https://morten-engen.no/      Unknown
# 2     8112536  http://www--wellsfargo--com--q149329d48d6c.wsi...      Unknown
# 3     8112535  http://sahatirollz.info/Y2w/NjYzMzVfdA/Mg/MzQ0...      Unknown
# 4     8112534  https://bafybeifjilrgbxbzztzp7z23hza7ccgtbqqsv...  VALID PHISH
# ...       ...                                                ...          ...
# 3995  8108543      https://jnpost.32125767.xyz/z6natlrc/wzDWnq/7      Unknown
# 3996  8108542  https://jnpost.506980798.xyz/z6natlrc/wzDWnq/7...      Unknown
# 3997  8108541        https://ollx.68654689.xyz/z6natlrc/wzDWnq/7      Unknown
# 3998  8108540        https://ollx.76547350.xyz/z6natlrc/wzDWnq/7      Unknown
# 3999  8108539        https://ollx.76547357.xyz/z6natlrc/wzDWnq/7      Unknown
#
#        online
# 0      ONLINE
# ...

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import time

url = 'https://phishtank.org/phish_archive.php?page={}'


trs = []
ids = []
phish_url = []
submitted = []
valid = []
online = []
date_added = []

for page in range(max_pages+1402, max_pages+1602):
#     print(f"Scraping page {page}")
    page_url = url.format(page)
    response = requests.get(page_url).text
    soup = BeautifulSoup(response, features="html.parser")
    trs += soup.find_all("td", class_="value")
#     print(f"Number of entries collected so far: {len(trs)}")
    time.sleep(pause_time)

for i in range(0,len(trs)):
    j = i % 5
    if i == 0 or j == 0:
        ids.append(trs[i].text)
        flag=trs[i].text
    elif i != 0 and j % 4 == 0:
        online.append(trs[i].text)
    elif i != 0 and j % 3 == 0:
        valid.append(trs[i].text)
    elif i != 0 and j % 2 == 0:
        #submitted.append(trs[i].text)
        pass
    else:
        phish_url.append(trs[i].contents[0].text)

data = {
    'id': ids,
    'phish_url': phish_url,
#    'submit_time': submitted,
    'valid': valid,
    'online': online
}

flag=0

df = pd.DataFrame(data)

url1 = 'https://phishtank.org/phish_detail.php?phish_id={}'


# for flag in df['id']:
#     page_url1 = url1.format(flag)
#     response1 = requests.get(page_url1).text
#     soup1 = BeautifulSoup(response1, features="html.parser")
#     trs1 = soup1.find_all("span")
#     time.sleep(pause_time)
#     pd.set_option('display.max_colwidth', None)
#     df['new phish_url']=repr(trs1[2].text)
            
print(df)
df.to_csv('phish_data7.csv', index=False)
# Out:
#            id                                      phish_url        valid  \
# 0     8108538    https://ollx.76547359.xyz/z6natlrc/wzDWnq/7      Unknown
# 1     8108537    https://ollx.76547351.xyz/z6natlrc/wzDWnq/7      Unknown
# 2     8108536    https://ollx.76547358.xyz/z6natlrc/wzDWnq/7      Unknown
# 3     8108535   https://ihpost.2383657.xyz/z6natlrc/wzDWnq/7      Unknown
# 4     8108534   https://ihpost.2383656.xyz/z6natlrc/wzDWnq/7      Unknown
# ...       ...                                            ...          ...
# 3995  8104543  https://maildinshaakckjnw577.firebaseapp.com/  VALID PHISH
# 3996  8104542          https://maildinshaakckjnw578.web.app/  VALID PHISH
# 3997  8104541  https://maildinshaakckjnw578.firebaseapp.com/  VALID PHISH
# 3998  8104540          https://maildinshaakckjnw579.web.app/  VALID PHISH
# 3999  8104539  https://maildinshaakckjnw579.firebaseapp.com/  VALID PHISH
#
#        online
# 0     Offline
# 1     Offline
# 2     Offline
# 3     Offline
# ...

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import time

url = 'https://phishtank.org/phish_archive.php?page={}'


trs = []
ids = []
phish_url = []
submitted = []
valid = []
online = []
date_added = []

for page in range(max_pages+1602, max_pages+1802):
#     print(f"Scraping page {page}")
    page_url = url.format(page)
    response = requests.get(page_url).text
    soup = BeautifulSoup(response, features="html.parser")
    trs += soup.find_all("td", class_="value")
#     print(f"Number of entries collected so far: {len(trs)}")
    time.sleep(pause_time)

for i in range(0,len(trs)):
    j = i % 5
    if i == 0 or j == 0:
        ids.append(trs[i].text)
        flag=trs[i].text
    elif i != 0 and j % 4 == 0:
        online.append(trs[i].text)
    elif i != 0 and j % 3 == 0:
        valid.append(trs[i].text)
    elif i != 0 and j % 2 == 0:
        #submitted.append(trs[i].text)
        pass
    else:
        phish_url.append(trs[i].contents[0].text)

data = {
    'id': ids,
    'phish_url': phish_url,
#    'submit_time': submitted,
    'valid': valid,
    'online': online
}

flag=0

df = pd.DataFrame(data)

url1 = 'https://phishtank.org/phish_detail.php?phish_id={}'


# for flag in df['id']:
#     page_url1 = url1.format(flag)
#     response1 = requests.get(page_url1).text
#     soup1 = BeautifulSoup(response1, features="html.parser")
#     trs1 = soup1.find_all("span")
#     time.sleep(pause_time)
#     pd.set_option('display.max_colwidth', None)
#     df['new phish_url']=repr(trs1[2].text)
            
print(df)
df.to_csv('phish_data8.csv', index=False)
# Out:
#            id                                      phish_url        valid  \
# 0     8104538          https://maildinshaakckjnw580.web.app/  VALID PHISH
# 1     8104537  https://maildinshaakckjnw580.firebaseapp.com/  VALID PHISH
# 2     8104536          https://maildinshaakckjnw581.web.app/  VALID PHISH
# 3     8104535  https://maildinshaakckjnw581.firebaseapp.com/  VALID PHISH
# 4     8104534          https://maildinshaakckjnw582.web.app/  VALID PHISH
# ...       ...                                            ...          ...
# 3995  8100543            https://phiendichvientiengnhat.net/      Unknown
# 3996  8100542                    https://dichthuatachau.com/      Unknown
# 3997  8100541                      https://alumicastore.com/      Unknown
# 3998  8100540                 https://vanchuyenvietnhat.net/      Unknown
# 3999  8100539                https://ghbaeietyh.duckdns.org/      Unknown
#
#        online
# 0     Offline
# 1     Offline
# 2     Offline
# 3     Offline
# ...

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import time

url = 'https://phishtank.org/phish_archive.php?page={}'


trs = []
ids = []
phish_url = []
submitted = []
valid = []
online = []
date_added = []

for page in range(max_pages+1802, max_pages+2002):
#     print(f"Scraping page {page}")
    page_url = url.format(page)
    response = requests.get(page_url).text
    soup = BeautifulSoup(response, features="html.parser")
    trs += soup.find_all("td", class_="value")
#     print(f"Number of entries collected so far: {len(trs)}")
    time.sleep(pause_time)

for i in range(0,len(trs)):
    j = i % 5
    if i == 0 or j == 0:
        ids.append(trs[i].text)
        flag=trs[i].text
    elif i != 0 and j % 4 == 0:
        online.append(trs[i].text)
    elif i != 0 and j % 3 == 0:
        valid.append(trs[i].text)
    elif i != 0 and j % 2 == 0:
        #submitted.append(trs[i].text)
        pass
    else:
        phish_url.append(trs[i].contents[0].text)

data = {
    'id': ids,
    'phish_url': phish_url,
#    'submit_time': submitted,
    'valid': valid,
    'online': online
}

flag=0

df = pd.DataFrame(data)

url1 = 'https://phishtank.org/phish_detail.php?phish_id={}'


# for flag in df['id']:
#     page_url1 = url1.format(flag)
#     response1 = requests.get(page_url1).text
#     soup1 = BeautifulSoup(response1, features="html.parser")
#     trs1 = soup1.find_all("span")
#     time.sleep(pause_time)
#     pd.set_option('display.max_colwidth', None)
#     df['new phish_url']=repr(trs1[2].text)
            
print(df)
df.to_csv('phish_data9.csv', index=False)
# Out:
#            id                                          phish_url    valid  \
# 0     8100538                    https://phiendichtiengphap.com/  Unknown
# 1     8100537                      https://www.fedexvietnam.net/  Unknown
# 2     8100536                                 SPAM-TO-BE-DELETED  Unknown
# 3     8100535                           https://aloquangcao.net/  Unknown
# 4     8100534                        https://vietnampost.online/  Unknown
# ...       ...                                                ...      ...
# 3995  8096543                              https://brasstax.net/  Unknown
# 3996  8096542                                https://nablogu.pl/  Unknown
# 3997  8096541  https://variety.com/2023/tv/reviews/succession...  Unknown
# 3998  8096540                             https://bit.ly/3ZdGstM  Unknown
# 3999  8096539  http://www.winzipsystemtools.com/sus/download-...  Unknown
#
#        online
# 0      ONLINE
# 1      ONLINE
# 2     Offline
# 3      ONLINE
# ...

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import time

url = 'https://phishtank.org/phish_search.php?page={}&valid=n&Search=Search'
max_pages = 1250 # set the number of pages you want to scrape
pause_time = 2  # set the pause time in seconds

trs = []
ids = []
phish_url = []
submitted = []
valid = []
online = []
date_added = []

for page in range(0, max_pages):
#     print(f"Scraping page {page}")
    page_url = url.format(page)
    response = requests.get(page_url).text
    soup = BeautifulSoup(response, features="html.parser")
    trs += soup.find_all("td", class_="value")
#     print(f"Number of entries collected so far: {len(trs)}")
    time.sleep(pause_time)


for i in range(0,len(trs)):
    j = i % 5
    if i == 0 or j == 0:
        ids.append(trs[i].text)
        flag=trs[i].text
    elif i != 0 and j % 4 == 0:
        online.append(trs[i].text)
    elif i != 0 and j % 3 == 0:
        valid.append(trs[i].text)
    elif i != 0 and j % 2 == 0:
        #submitted.append(trs[i].text)
        pass
    else:
        phish_url.append(trs[i].contents[0].text)

data = {
    'id': ids,
    'phish_url': phish_url,
#    'submit_time': submitted,
    'valid': valid,
    'online': online
}

flag=0

df = pd.DataFrame(data)
print(df)
df.to_csv('phish_data_invalid_2.csv', index=False)
